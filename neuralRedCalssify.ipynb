# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroR2/LeandroR2/blob/main/neuralRedCalssify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles

# %%
# Crear el Datasets

n = 500
p = 2

X, Y = make_circles(n_samples= n, factor= 0.5, noise= 0.05)

plt.scatter(X[Y == 0, 0], X[Y == 0, 1], c= "violet")
plt.scatter(X[Y == 1, 0], X[Y == 1, 1], c= "green")
plt.axis("equal")
plt.show()

# %%
# Clase de la capa de la red

class neural_layer():
    def __init__(self, n_conn, n_neu, act_f):
      self.act_f = act_f
      self.b = np.random.rand(1, n_neu)      * 2 - 1
      self.W = np.random.rand(n_conn, n_neu) * 2 - 1

# %%
# Funciones de activación

sigm = (lambda x: 1/(1 + np.e ** (-x)),
        lambda x: x * (1 - x))

_x = np.linspace(-5, 5, 100)
plt.plot(_x, sigm[1](_x))

# %%
# Creando capas de la red

def create_nn(topology, act_f):
  nn = []
  for l, layer in enumerate(topology[:-1]):
    nn.append(neural_layer(topology[l], topology[l+1], act_f))

  return nn
# Out:
# [<__main__.neural_layer at 0x7c1cf1f5d840>,
#  <__main__.neural_layer at 0x7c1cf1f5c610>,
#  <__main__.neural_layer at 0x7c1cf1f5cb80>,
#  <__main__.neural_layer at 0x7c1cf1f5f0a0>,
#  <__main__.neural_layer at 0x7c1cf1f5ec50>,
#  <__main__.neural_layer at 0x7c1cf1f5ee30>]

# %%
topology = [p, 4, 8, 16, 8, 4, 1]

neural_net = create_nn(topology, sigm)

l2_loss = (lambda Yp, Yr: np.mean((Yp - Yr) ** 2),
           lambda Yp, Yr: (Yp - Yr))

def train(neural_net, X, Y, l2_loss, lr=0.5):
